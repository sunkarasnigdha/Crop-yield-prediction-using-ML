# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
df = pd.read_csv("yield_df.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           28242 non-null  object
#  1   Item                           28242 non-null  object
#  2   Year                           28242 non-null  int64
#  3   hg/ha_yield                    28242 non-null  int64
#  4   average_rain_fall_mm_per_year  28242 non-null  float64
#  5   pesticides_tonnes              28242 non-null  float64
#  6   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2310)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (25932, 7)

# %%
df.describe()
# Out:
#                Year    hg/ha_yield  average_rain_fall_mm_per_year  \
# count  25932.000000   25932.000000                   25932.000000
# mean    2001.556455   76978.132925                    1146.836688
# std        7.055924   84647.605552                     717.391098
# min     1990.000000      50.000000                      51.000000
# 25%     1995.000000   19996.000000                     593.000000
# 50%     2001.000000   39530.000000                    1083.000000
# 75%     2008.000000  104168.000000                    1668.000000
# max     2013.000000  501412.000000                    3240.000000
#
#        pesticides_tonnes      avg_temp
# count       25932.000000  25932.000000
# mean        34782.573241     20.422251
# std         57228.568244      6.439402
# min             0.040000      1.300000
# 25%          1597.000000     16.580000
# 50%         15373.000000     21.420000
# 75%         45620.000000     26.060000
# max        367778.000000     30.650000

# %%
# df.corr()

# %%
# Data Visualization

# %%
len(df['Area'].unique())
# Out:
# 101

# %%
len(df['Item'].unique())
# Out:
# 10

# %%
plt.figure(figsize=(15,20))
sns.countplot(y = df['Area'])
plt.show()

# %%
plt.figure(figsize=(15,20))
sns.countplot(y = df['Item'])
plt.show()

# %%
(df['Area'].value_counts() <400).sum()
# Out:
# np.int64(88)

# %%
country = df['Area'].unique()
yield_per_country = []
for state in country:
    yield_per_country.append(df[df['Area'] == state]['hg/ha_yield'].sum())

# %%
df['hg/ha_yield'].sum()
# Out:
# np.int64(1996196943)

# %%
yield_per_country
# Out:
# [np.int64(5711536),
#  np.int64(6711464),
#  np.int64(5722563),
#  np.int64(32864032),
#  np.int64(4524100),
#  np.int64(109111062),
#  np.int64(10852258),
#  np.int64(4608380),
#  np.int64(4384717),
#  np.int64(4443889),
#  np.int64(7720159),
#  np.int64(4704812),
#  np.int64(8442270),
#  np.int64(470651),
#  np.int64(136340329),
#  np.int64(6263075),
#  np.int64(6083337),
#  np.int64(7031146),
#  np.int64(10717883),
#  np.int64(34706922),
#  np.int64(4255627),
#  np.int64(20561214),
#  np.int64(26927138),
#  np.int64(6083167),
#  np.int64(10701651),
#  np.int64(25312166),
#  np.int64(21315591),
#  np.int64(36828848),
#  np.int64(16855944),
#  np.int64(1452416),
#  np.int64(3595638),
#  np.int64(6210668),
#  np.int64(15790618),
#  np.int64(38780463),
#  np.int64(9260371),
#  np.int64(14571925),
#  np.int64(16508723),
#  np.int64(7975743),
#  np.int64(8361103),
#  np.int64(8619194),
#  np.int64(10920131),
#  np.int64(8824110),
#  np.int64(274219558),
#  np.int64(68067328),
#  np.int64(10984722),
#  np.int64(9104030),
#  np.int64(32280700),
#  np.int64(19698007),
#  np.int64(100924145),
#  np.int64(9965212),
#  np.int64(14391737),
#  np.int64(3698588),
#  np.int64(6956804),
#  np.int64(4258932),
#  np.int64(9016288),
#  np.int64(4174348),
#  np.int64(6103523),
#  np.int64(8346715),
#  np.int64(7934982),
#  np.int64(15106720),
#  np.int64(4465841),
#  np.int64(12684212),
#  np.int64(113698872),
#  np.int64(1645100),
#  np.int64(22173010),
#  np.int64(6964027),
#  np.int64(3165475),
#  np.int64(4113713),
#  np.int64(14086433),
#  np.int64(17657728),
#  np.int64(12819227),
#  np.int64(12316327),
#  np.int64(6721305),
#  np.int64(49264956),
#  np.int64(10729929),
#  np.int64(15201910),
#  np.int64(6564711),
#  np.int64(12154347),
#  np.int64(5995626),
#  np.int64(6006156),
#  np.int64(7741053),
#  np.int64(15171886),
#  np.int64(10342677),
#  np.int64(7197013),
#  np.int64(30999849),
#  np.int64(46773540),
#  np.int64(11217741),
#  np.int64(1896346),
#  np.int64(14786468),
#  np.int64(8620653),
#  np.int64(13336346),
#  np.int64(6295210),
#  np.int64(9511720),
#  np.int64(3724246),
#  np.int64(52263950),
#  np.int64(7494314),
#  np.int64(5496901),
#  np.int64(44335992),
#  np.int64(9539820),
#  np.int64(7254311),
#  np.int64(7408629)]

# %%
plt.figure(figsize=(15,20))
sns.barplot(y = country, x = yield_per_country)
plt.show()

# %%
crops = df['Item'].unique()
yield_per_crop = []
for crop in crops:
    yield_per_crop.append(df[df['Item'] == crop]['hg/ha_yield'].sum())

# %%
plt.figure(figsize=(15,20))
sns.barplot(y = crops, x = yield_per_crop)
plt.show()

# %%
df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
df.columns
# Out:
# Index(['Area', 'Item', 'Year', 'hg/ha_yield', 'average_rain_fall_mm_per_year',
#        'pesticides_tonnes', 'avg_temp'],
#       dtype='object')

# %%
col = ['Year','average_rain_fall_mm_per_year','pesticides_tonnes', 'avg_temp','Area', 'Item', 'hg/ha_yield']

# %%
df = df[col]

# %%
df.head()
# Out:
#    Year  average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp     Area  \
# 0  1990                         1485.0              121.0     16.37  Albania
# 1  1990                         1485.0              121.0     16.37  Albania
# 2  1990                         1485.0              121.0     16.37  Albania
# 3  1990                         1485.0              121.0     16.37  Albania
# 4  1990                         1485.0              121.0     16.37  Albania
#
#           Item  hg/ha_yield
# 0        Maize        36613
# 1     Potatoes        66667
# 2  Rice, paddy        23333
# 3      Sorghum        12500
# 4     Soybeans         7000

# %%
X = df.drop('hg/ha_yield', axis = 1)
y = df['hg/ha_yield']

# %%
X.shape
# Out:
# (25932, 6)

# %%
y.shape
# Out:
# (25932,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0, shuffle=True)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

ohe = OneHotEncoder(drop = 'first')
scale = StandardScaler()

preprocessor = ColumnTransformer(
    transformers = [
        ('StandardScale', scale, [0,1,2,3]),
        ('OneHotEncode', ohe, [4,5])
    ], 
    remainder = 'passthrough'
)

# %%
X_train_dummy = preprocessor.fit_transform(X_train)
X_test_dummy  = preprocessor.fit_transform(X_test)

# %%
preprocessor.get_feature_names_out(col[:-1])
# Out:
# array(['StandardScale__Year',
#        'StandardScale__average_rain_fall_mm_per_year',
#        'StandardScale__pesticides_tonnes', 'StandardScale__avg_temp',
#        'OneHotEncode__Area_Algeria', 'OneHotEncode__Area_Angola',
#        'OneHotEncode__Area_Argentina', 'OneHotEncode__Area_Armenia',
#        'OneHotEncode__Area_Australia', 'OneHotEncode__Area_Austria',
#        'OneHotEncode__Area_Azerbaijan', 'OneHotEncode__Area_Bahamas',
#        'OneHotEncode__Area_Bahrain', 'OneHotEncode__Area_Bangladesh',
#        'OneHotEncode__Area_Belarus', 'OneHotEncode__Area_Belgium',
#        'OneHotEncode__Area_Botswana', 'OneHotEncode__Area_Brazil',
#        'OneHotEncode__Area_Bulgaria', 'OneHotEncode__Area_Burkina Faso',
#        'OneHotEncode__Area_Burundi', 'OneHotEncode__Area_Cameroon',
#        'OneHotEncode__Area_Canada',
#        'OneHotEncode__Area_Central African Republic',
#        'OneHotEncode__Area_Chile', 'OneHotEncode__Area_Colombia',
#        'OneHotEncode__Area_Croatia', 'OneHotEncode__Area_Denmark',
#        'OneHotEncode__Area_Dominican Republic',
#        'OneHotEncode__Area_Ecuador', 'OneHotEncode__Area_Egypt',
#        'OneHotEncode__Area_El Salvador', 'OneHotEncode__Area_Eritrea',
#        'OneHotEncode__Area_Estonia', 'OneHotEncode__Area_Finland',
#        'OneHotEncode__Area_France', 'OneHotEncode__Area_Germany',
#        'OneHotEncode__Area_Ghana', 'OneHotEncode__Area_Greece',
#        'OneHotEncode__Area_Guatemala', 'OneHotEncode__Area_Guinea',
#        'OneHotEncode__Area_Guyana', 'OneHotEncode__Area_Haiti',
#        'OneHotEncode__Area_Honduras', 'OneHotEncode__Area_Hungary',
#        'OneHotEncode__Area_India', 'OneHotEncode__Area_Indonesia',
#        'OneHotEncode__Area_Iraq', 'OneHotEncode__Area_Ireland',
#        'OneHotEncode__Area_Italy', 'OneHotEncode__Area_Jamaica',
#        'OneHotEncode__Area_Japan', 'OneHotEncode__Area_Kazakhstan',
#        'OneHotEncode__Area_Kenya', 'OneHotEncode__Area_Latvia',
#        'OneHotEncode__Area_Lebanon', 'OneHotEncode__Area_Lesotho',
#        'OneHotEncode__Area_Libya', 'OneHotEncode__Area_Lithuania',
#        'OneHotEncode__Area_Madagascar', 'OneHotEncode__Area_Malawi',
#        'OneHotEncode__Area_Malaysia', 'OneHotEncode__Area_Mali',
#        'OneHotEncode__Area_Mauritania', 'OneHotEncode__Area_Mauritius',
#        'OneHotEncode__Area_Mexico', 'OneHotEncode__Area_Montenegro',
#        'OneHotEncode__Area_Morocco', 'OneHotEncode__Area_Mozambique',
#        'OneHotEncode__Area_Namibia', 'OneHotEncode__Area_Nepal',
#        'OneHotEncode__Area_Netherlands', 'OneHotEncode__Area_New Zealand',
#        'OneHotEncode__Area_Nicaragua', 'OneHotEncode__Area_Niger',
#        'OneHotEncode__Area_Norway', 'OneHotEncode__Area_Pakistan',
#        'OneHotEncode__Area_Papua New Guinea', 'OneHotEncode__Area_Peru',
#        'OneHotEncode__Area_Poland', 'OneHotEncode__Area_Portugal',
#        'OneHotEncode__Area_Qatar', 'OneHotEncode__Area_Romania',
#        'OneHotEncode__Area_Rwanda', 'OneHotEncode__Area_Saudi Arabia',
#        'OneHotEncode__Area_Senegal', 'OneHotEncode__Area_Slovenia',
#        'OneHotEncode__Area_South Africa', 'OneHotEncode__Area_Spain',
#        'OneHotEncode__Area_Sri Lanka', 'OneHotEncode__Area_Sudan',
#        'OneHotEncode__Area_Suriname', 'OneHotEncode__Area_Sweden',
#        'OneHotEncode__Area_Switzerland', 'OneHotEncode__Area_Tajikistan',
#        'OneHotEncode__Area_Thailand', 'OneHotEncode__Area_Tunisia',
#        'OneHotEncode__Area_Turkey', 'OneHotEncode__Area_Uganda',
#        'OneHotEncode__Area_Ukraine', 'OneHotEncode__Area_United Kingdom',
#        'OneHotEncode__Area_Uruguay', 'OneHotEncode__Area_Zambia',
#        'OneHotEncode__Area_Zimbabwe', 'OneHotEncode__Item_Maize',
#        'OneHotEncode__Item_Plantains and others',
#        'OneHotEncode__Item_Potatoes', 'OneHotEncode__Item_Rice, paddy',
#        'OneHotEncode__Item_Sorghum', 'OneHotEncode__Item_Soybeans',
#        'OneHotEncode__Item_Sweet potatoes', 'OneHotEncode__Item_Wheat',
#        'OneHotEncode__Item_Yams'], dtype=object)

# %%
from sklearn.linear_model import LinearRegression,Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, r2_score, accuracy_score

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Lasso' : Lasso(),
    'Ridge' : Ridge(),
    'Decision Tree': DecisionTreeRegressor(),
    'KNN': KNeighborsRegressor(),
}

for name, md in models.items():
    md.fit(X_train_dummy,y_train)
    y_pred = md.predict(X_test_dummy)
    print(f"{name}: mae : {mean_absolute_error(y_test, y_pred)} score : {r2_score(y_test, y_pred)}")
# Out:
# Linear Regression: mae : 29897.284815550447 score : 0.7472732839987297
# C:\Users\Hello\AppData\Roaming\Python\Python313\site-packages\sklearn\linear_model\_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.728e+10, tolerance: 1.485e+10
#   model = cd_fast.sparse_enet_coordinate_descent(
# Lasso: mae : 29883.83065207178 score : 0.7472938374682814
# Ridge: mae : 29852.948898834806 score : 0.74726257856193
# Decision Tree: mae : 5416.644303065355 score : 0.9695813291549173
# KNN: mae : 4683.468517447465 score : 0.9845945880467103

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train_dummy,y_train)
dtr.predict(X_test_dummy)
# Out:
# array([35286., 22814., 19295., ..., 11488., 34879., 77391.], shape=(5187,))

# %%
df.columns
# Out:
# Index(['Year', 'average_rain_fall_mm_per_year', 'pesticides_tonnes',
#        'avg_temp', 'Area', 'Item', 'hg/ha_yield'],
#       dtype='object')

# %%
df.head()
# Out:
#    Year  average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp     Area  \
# 0  1990                         1485.0              121.0     16.37  Albania
# 1  1990                         1485.0              121.0     16.37  Albania
# 2  1990                         1485.0              121.0     16.37  Albania
# 3  1990                         1485.0              121.0     16.37  Albania
# 4  1990                         1485.0              121.0     16.37  Albania
#
#           Item  hg/ha_yield
# 0        Maize        36613
# 1     Potatoes        66667
# 2  Rice, paddy        23333
# 3      Sorghum        12500
# 4     Soybeans         7000

# %%
# Predictive System

# %%
def prediction(Year, average_rain_fall_mm_per_year,pesticides_tonnes, avg_temp, Area, Item):
    features = np.array([[Year, average_rain_fall_mm_per_year,pesticides_tonnes, avg_temp, Area, Item]], dtype = object)
    transform_features = preprocessor.transform(features)
    predicted_yield = dtr.predict(transform_features).reshape(-1,1)
    return predicted_yield[0][0]

# %%
result = prediction(1990,1485.0,121.0,16.37,'Albania','Maize')
# Out:
# C:\Users\Hello\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\Hello\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# np.float64(36613.0)

# %%
import pickle
pickle.dump(dtr, open("dtr.pkl","wb"))
pickle.dump(preprocessor, open("preprocessor.pkl","wb"))
